# %% [markdown]
# <a href="https://colab.research.google.com/github/DINH20104022/2014022-Hung-Minh-Tran-Dinh/blob/main/Tran%60_Di_nh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt', mode='w') as accounts:
  accounts.write('1 Nguyen Van A 8.0\n')
  accounts.write('2 Le Thi B 6.8\n')

# %%
with open('text.txt', mode= 'w') as accounts:
  print('7:00 Nguyen Van A', file= accounts)
  print('7:30 Con Bo Cuoi', file= accounts)

# %%
with open ('/content/text.txt', mode='r') as accounts:
  print(f'{'name':<1}{'score':>1}')
  for record in accounts:
    name, score = record.split()
    print(f'{name:<1}{score:>1}')

# %%
import pandas as pd
url= 'Book1.csv'
dataframe= pd.read_csv(url)
dataframe.head(5)

# %% [markdown]
# import pandas as pd
# dataframe = pd.DataFrame()
# dataframe['Name'] = ['Jack 5trieu', ' Steven Job']
# dataframe['Age'] = ['38, 300']
# dataframe['Drive'] = [ True, False]
# dataframe

# %%
import pandas as pd 
dataframe = pd.DataFrame()
dataframe['Name'] = ['Jack 5trieu', ' Steven Job']
dataframe['Age'] = [38, 30]
dataframe['Drive'] = [ True, False]
dataframe
# Out:
#           Name  Age  Drive
# 0  Jack 5trieu   38   True
# 1   Steven Job   30  False

# %%
import pandas as pd
url= 'Book1.csv'
dataframe= pd.read_csv(url)
dataframe.iloc[:4]

# %%
import pandas as pd
url= 'Book1.csv'
dataframe= pd.read_csv(url)
dataframe[(dataframe['hoa']=='vang`') & (dataframe['account no amount'] == 4)]
# Out:
# Empty DataFrame
# Columns: [serial no, date, account no amount, Unnamed: 3, hoa]
# Index: []

# %% [markdown]
# # Mục mới

# %%
import pandas as pd
url= 'Book1.csv'
dataframe= pd.read_csv(url)
dataframe['hoa'].unique()
# Out:
# array(['vang`', 'do?'], dtype=object)

# %%
import pandas as pd
url= 'Book1.csv'
dataframe= pd.read_csv(url)
dataframe['hoa'].value_counts()
# Out:
# vang`    5
# do?      5
# Name: hoa, dtype: int64

# %%
import pandas as pd 
url= 'Book1.csv'
dataframe = pd.read_csv(url)
dataframe.drop('date', axis=1).head(9)
# Out:
#    serial no  account no amount  Unnamed: 3    hoa
# 0          1                  1         500  vang`
# 1          2                  2         200    do?
# 2          3                  3          13  vang`
# 3          4                  4        1999    do?
# 4          5                  5        1200  vang`
# 5          6                  6         300  vang`
# 6          7                  7         600    do?
# 7          8                  8         410    do?
# 8          9                  9         150    do?

# %%
import pandas as pd
url= 'Book1.csv'
dataframe= pd.read_csv(url)
dataframe.groupby(['date','hoa'])['serial no'].count()
# Out:
# date      hoa
# 1/2/2015  vang`    1
# 1/3/2015  do?      1
# 1/4/2015  vang`    1
# 1/5/2015  do?      1
# 1/6/2015  vang`    1
# 1231      do?      2
# 1231845   vang`    1
# 21312     do?      1
# 23123     vang`    1
# Name: serial no, dtype: int64

# %%
import pandas as pd
url= 'http://winterolympicsmedals.com/medals.csv'
data= pd.read_csv(url)
data[(data['Medal']== 'Gold') & (data['NOC']=='USA')& (data['Year']<=2000) & (data['Event gender'] != 'W')].head(500).count()
# Out:
# Year            33
# City            33
# Sport           33
# Discipline      33
# NOC             33
# Event           33
# Event gender    33
# Medal           33
# dtype: int64

# %%
from openpyxl import Workbook 
wb = Workbook()
sheet= wb.active
sheet['A1']= 'Nguyen Van A'
sheet['B1']= ' 20104001'
sheet['A2']= 'Lai Tri Minh'
sheet['B2']= '20104044'
wb.save('test.xlsx')

# %%
import openpyxl
wb = openpyxl.load_workbook('test.xlsx')
sheet= wb.active
t1= sheet['A1']
t2= sheet['B1']
t3= sheet.cell(row = 2, column=1)
t4= sheet.cell(row = 2, column=2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Nguyen Van A  20104001
# Lai Tri Minh 20104044

# %%
my_wb_obj = openpyxl.load.workbook(path)
my_sheet_obj= my_wb_obj.active
my_row = my_sheet_obj.max_row
for i in range(1, my_row + 1):
  cell_obj= my_sheet_obj.cell(row = i, column=1)
  print(cell_obj.value)

# %% [markdown]
# # Mục mới

# %%
import openpyxl
my_wb= openpyxl.Workbook()
my_sheet= my_wb.active
c1= my_sheet.cell(row=1, column=1)
c1.value = 'Hung Minh Tran Dinh'
c2= my_sheet.cell(row=1, column=2)
c2.vulue= 'Lai Tri Minh'
c3= my_sheet['A2']
c3.value="RO'BO`VIP"
c4= my_sheet['B2']
c4.value ="VIPRO"
my_wb.save('‪C:\Users\asus\Downloads\adua.xlsx')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y= x +1
plt.plot(x,y,'o--')
plt.show()

# %%
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.title('y=x and y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
N=16
x = np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
N=16
x=np.linspace(0,15,16)
y=np.linspace(0.1,2,16)
plt.plot(x,y,'o--')
plt.show()

# %%
x=[4,5,3,1,6,7]
plt.plot(x)
plt.show()

# %%
x=np.arange(25)
plt.plot(x)
plt.show()

# %%
x= np.arange(25)
plt.plot(x,(x**3)+1)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2)
plt.plot(x, -x**3)
plt.plot(x, -2*x)
plt.plot(x,-2**x)
plt.show()

# %%
x=np.arange(7)
plt.plot(x,-x**2,x,-x**3,x,-2*x,x,-2**x)
plt.grid(True)
plt.savefig('dothi.png')
plt.show()

# %%
x= np.arange(3)
plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2,color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3,color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x, color= 'b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.axis([0,100,0,10])
plt.scatter(60,5, s=1000, color= 'b', alpha=1)
plt.scatter(80,5, s=1000, color = 'b', alpha=.5)
plt.scatter(90,5,s=1000, color= 'b', alpha=.1)
plt.show()

# %%
plt.plot([4,3],[7,2],linewidth=5, color='r')
plt.text(3,3,'TC')
# Out:
# Text(3, 3, 'TC')

# %%
plt.axis([0,50,0,10])
plt.arrow(10,5,0,-7,head_length=4, head_width=5, color='g')
plt.show()

# %%
x=np.arange(4)
g=np.random.rand(4)
plt.bar(x,g)
plt.show()

# %%
y=np.random.rand(3,4)
plt.bar(x+0,y[0], color='b', width=0.25)
plt.bar(x+0.25,y[1], color= 'y', width= 0.25)
plt.bar(x+0.5,y[2], color= 'r', width= 0.25)
plt.show()

# %%
N=1000
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
size= 20
plt.scatter (x,y,s=size, c= colors, alpha=1)
plt.show()

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 4.1 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=a8c43405214f601c0e9c3003811ec57936f0df01f334dd7e175c8ad584d5cda6
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
x=np.arange(11)
nfx= fuzz.trimf(x,[0,5,10])

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrt
food=ctrt.Antecedent(np.arange(0,11,1),'food')
service = ctrt.Antecedent(np.arange(0,11,1),'service')
tip= ctrt.Consequent(np.arange(10,25,1),'tip')
food['poor']=fuzz.trimf(food.universe, [0,0,5])
food['average']= fuzz.trimf(food.universe,[0,5,10])
food['good']=fuzz.trimf(food.universe,[5,10,10])
service['poor']=fuzz.trimf(service.universe,[0,0,5])
service['average']=fuzz.trimf(service.universe,[0,5,10])
service['good']=fuzz.trimf(service.universe,[5,10,10])
tip['poor']=fuzz.trimf(tip.universe,[10,14,18])
tip['average']=fuzz.trimf(tip.universe,[14,18,22])
tip['good']=fuzz.trimf(tip.universe,[18,22,25])
service.view()
food.view()
tip.view()

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
'''Antecedent: đầu vào
Consequent: ouput(kết quả)'''
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Consequent(np.arange(10,26,1),'tip')
food['poor']=fuzz.trimf(food.universe,[0,0,5])
food['average']=fuzz.trimf(food.universe,[0,5,10])
food['good']=fuzz.trimf(food.universe,[5,10,10])
service['poor']=fuzz.trimf(service.universe,[0,0,5])
service['average']=fuzz.trimf(service.universe,[0,5,10])
service['good']=fuzz.trimf(service.universe,[5,10,10])
tip['less']=fuzz.trimf(tip.universe,[10,14,18])
tip['normal']=fuzz.trimf(tip.universe,[14,18,22])
tip['much']=fuzz.trimf(tip.universe,[18,22,25])
food.view()
service.view()
tip.view()
tip['normal'].view()
rule1 = ctrl.Rule(food['poor']&service['poor'],tip['less'])
rule2 = ctrl.Rule(food['poor']&service['average'],tip['less'])
rule3 = ctrl.Rule(food['poor']&service['good'],tip['normal'])
rule4 = ctrl.Rule(food['average']&service['poor'],tip['less'])
rule5 = ctrl.Rule(food['average']&service['average'],tip['normal'])
rule6 = ctrl.Rule(food['average']&service['good'],tip['much'])
rule7 = ctrl.Rule(food['good']&service['poor'],tip['normal'])
rule8 = ctrl.Rule(food['good']&service['average'],tip['much'])
rule9 = ctrl.Rule(food['good']&service['good'],tip['much'])
tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6, rule7,rule8,rule9])
tipping = ctrl.ControlSystemSimulation(tipping_ctrl)
tipping.input['food'] = 6.2
tipping.input['service'] = 3.5
tipping.compute()
print(tipping.output['tip'])
tip.view(sim=tipping)
# Out:
# 17.516163602679207

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Mục mới

# %%
from networkx.algorithms.bipartite.basic import color
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
time = ctrl.Antecedent(np.arange(10,123,7),'time')
rice = ctrl.Antecedent(np.arange(100,1100,5),'rice')
power = ctrl.Consequent(np.arange(0,1.5,0.3),'power') 
time['vshort']= fuzz.trimf(time.universe,[10,10,20])
time['short']= fuzz.trimf(time.universe,[10,20,30])
time['enough']= fuzz.trimf(time.universe,[20,30,80])
time['long']= fuzz.trimf(time.universe,[30,80,110])
time['vlong']= fuzz.trimf(time.universe,[80,110,120])
rice['com song']= fuzz.trimf(rice.universe,[100,100,300])
rice['com nhao']= fuzz.trimf(rice.universe,[100,300,500])
rice['com vua chin']= fuzz.trimf(rice.universe,[300,500,900])
rice['com chay']= fuzz.trimf(rice.universe,[500,900,1000])
power['yeu']= fuzz.trimf(power.universe,[0,0,0.2])
power['binh thuong']= fuzz.trimf(power.universe,[0,0.2,0.6])
power['hoi manh']= fuzz.trimf(power.universe,[0.2,0.6,0.7])
power['manh']= fuzz.trimf(power.universe,[0.7,1,1])
time.view()
rice.view()
power.view()
power['binh thuong'].view()
rule1=ctrl.Rule(time['vlong'] & rice['com song'], power['yeu'])
rule2=ctrl.Rule(time['vlong'] & rice['com nhao'],power['yeu'])
rule3=ctrl.Rule(time['vlong'] & rice['com chay'],power['manh'])

rule4=ctrl.Rule(time['short'] & rice['com song'],power['yeu'])
rule5=ctrl.Rule(time['short'] & rice['com nhao'],power['binh thuong'])

rule6=ctrl.Rule(time['enough'] & rice['com chay'],power['manh'])
rule7=ctrl.Rule(time['enough'] & rice['com song'],power['binh thuong'])

rule8=ctrl.Rule(time['long'] & rice['com nhao'],power['binh thuong'])
rule9=ctrl.Rule(time['long'] & rice['com chay'],power['manh'])

rule10=ctrl.Rule(time['vlong'] & rice['com vua chin'],power['hoi manh'])
rule11=ctrl.Rule(time['vlong'] & rice['com nhao'],power['binh thuong'])
rule12=ctrl.Rule(time['vlong'] & rice['com song'],power['binh thuong'])
rule13=ctrl.Rule(time['vlong'] & rice['com chay'],power['manh'])

powerinput_ctrl=ctrl.ControlSystem([rule1,rule2,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13])
powerinput=ctrl.ControlSystemSimulation(powerinput_ctrl)
powerinput.input['time']= 47
powerinput.input['rice'] = 789
powerinput.compute()
print(powerinput.output['power'])
power.view(sim=powerinput)
# Out:
# 0.8999999999999999

# %%
from networkx.algorithms.bipartite.basic import color
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
windspeed = ctrl.Antecedent(np.arange(0.7,3.1,0.5),'windspeed')
temperature = ctrl.Antecedent(np.arange(20.4,41.2,5),'temperature')
rainfall = ctrl.Consequent(np.arange(0.2,9.1,1),'rainfall') 
windspeed['low']= fuzz.trimf(windspeed.universe,[0.7,0.9,2])
windspeed['medium']= fuzz.trimf(windspeed.universe,[0.9,2,3.1])
windspeed['high']= fuzz.trimf(windspeed.universe,[2,3.1,3.1])
temperature['low']= fuzz.trimf(temperature.universe,[20.4,25.5,30])
temperature['medium']= fuzz.trimf(temperature.universe,[25.5,30,35.6])
temperature['high']= fuzz.trimf(temperature.universe,[35.6,39.7,41.2])
rainfall['low']= fuzz.trimf(rainfall.universe,[0.2,0.4,5])
rainfall['medium']= fuzz.trimf(rainfall.universe,[0.4,5,8.4])
rainfall['high']= fuzz.trimf(rainfall.universe,[5,8.4,9.1])

windspeed.view()
temperature.view()
rainfall.view()
rainfall['medium'].view()
rule1=ctrl.Rule(windspeed['low'] & temperature['low'], rainfall['low'])
rule2=ctrl.Rule(windspeed['low'] & temperature['medium'],rainfall['medium'])
rule3=ctrl.Rule(windspeed['low'] & temperature['high'],rainfall['high'])
rule4=ctrl.Rule(windspeed['medium'] & temperature['low'],rainfall['low'])
rule5=ctrl.Rule(windspeed['medium'] & temperature['medium'],rainfall['high'])
rule6=ctrl.Rule(windspeed['medium'] & temperature['high'],rainfall['high'])
rule7=ctrl.Rule(windspeed['high'] & temperature['low'],rainfall['low'])
rule8=ctrl.Rule(windspeed['high'] & temperature['medium'],rainfall['medium'])
rule9=ctrl.Rule(windspeed['high'] & temperature['high'],rainfall['high'])

rain_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
rain=ctrl.ControlSystemSimulation(rain_ctrl)
rain.input['windspeed'] = 1.5
rain.input['temperature'] = 37
rain.compute()
print(rain.output['rainfall'])
rainfall.view(sim=rain)
# Out:
# 5.939762674632173

# %%
from networkx.algorithms.bipartite.basic import color
import numpy as np
import skfuzzy as fuzzy
from skfuzzy import control as ctrl
height = ctrl.Antecedent(np.arange(),'height')
weight = ctrl.Antecedent(np.arange(),'weight')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/drive/MyDrive/DOWLOAD/Thư mục không có tiêu đề/Salary_Data.csv')
data.head()
data.shape
x=data.drop(['Salary'], axis=True)
y=data['Salary']
print(y)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
sns.pairplot(data)
plt.plot(x_train,y_train,'r', label='Train Data')
plt.xlabel('Year Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test).round(1)
cal=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Salary','Predict Salary'])
print('Coeffient',model.coef_)
print('Intercept',model.intercept_)
print('Accuracy',model.score(x_test,y_test))
plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_train,model.predict(x_train),color='blue')
plt.title('Salary vs Exrience')
plt.xlabel('Years of Exprience')
plt.ylabel('Salary')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-946bbeb35558> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(x_train,y_train)
#       4 y_pred=model.predict(x_test).round(1)
#       5 cal=pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Salary','Predict Salary'])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     661
#     662         X, y = self._validate_data(
# --> 663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#     665
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %%
import numpy as up
from  sklearn.linear_model import Perceptron
x=[[-0.5,-0.5],[-0.5,0.5],[0.3,-0.5],[-0.1,1]]
y=[1,1,0,0]
model= Perceptron()
model.fit(x,y)
print('Do chinh xac',model.score(x,y))
x_test=[[-0.5,0],[-0.1,-0.2],[1,-0.5],[0.4,-0.4]]
y_test=model.predict(x_test)
print(y_test)
# Out:
# Do chinh xac 1.0
# [1 1 0 0]

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/DOWLOAD/Thư mục không có tiêu đề/crabs.csv')
x = data.drop(['sex', 'speies','index'], axis= True)
data['sex'].replace('M,1')
data['sex'].replace('F,0')
y = data['sex']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
model= Perceptron()
model.fit(x,y)
print('Do chinh xac', model.score(x,y))
x_u = [[8.6,6.6,10.1,17,7],[9.7,8.4,20.7,24.4,5.3],[3.7,9.8,4.9,5.1,18.9]]
y_u = model.predict(x_u)
print(y_u)
# Out:
# Do chinh xac 0.89
# ['F' 'F' 'F']
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
import pandas as pd

url = "/content/drive/MyDrive/DOWLOAD/Thư mục không có tiêu đề/crabs.csv"
data = pd.read_csv(url)
x = data.drop(data.columns[[0,1,2]], axis=1)
y = data["sex"].replace(["M","F"],['1','0'])

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

model = Perceptron()
model.fit(x_train, y_train)
print("Độ chính xác: ", model.score(x_train,y_train))

x_u = [[8.6,6.6,10.1,17,7],[10.4,9.7,21.7,25.4,8.3]]
y_u = model.predict(x_u)

print(y_u)
# Out:
# Độ chính xác:  0.6285714285714286
# ['0' '0']
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
import pandas as pd

url = "/content/drive/MyDrive/DOWLOAD/Thư mục không có tiêu đề/iris.csv"
data = pd.read_csv(url)
data=data[:100]
x = data.drop(['variety'], axis= True)
y = data["variety"].replace(['Setosa','Versicolor','Virgineca'],['1','0','0'])
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)
model = Perceptron()
model.fit(x, y)
print("Độ chính xác: ", model.score(x,y))
x_zo = [[5.6,2.6,3.1,7,5.4],[2.4,4.7,1.7,5.4,8.3]]
y_re = model.predict(x_zo)
print('Accuracy',model.score(x,y))
print(y_re)
# Out:
# Độ chính xác:  1.0
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   "X does not have valid feature names, but"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-d5ada194fc62> in <module>
#      14 print("Độ chính xác: ", model.score(x,y))
#      15 x_zo = [[5.6,2.6,3.1,7,5.4],[2.4,4.7,1.7,5.4,8.3]]
# ---> 16 y_re = model.predict(x_zo)
#      17 print('Accuracy',model.score(x,y))
#      18 print(y_re)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# ...

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_iris
import pandas as pd
url = '/content/drive/MyDrive/DOWLOAD/Thư mục không có tiêu đề/iris.csv'
data = pd.read_csv(url)
data = data[:100]
x= data.drop(['variety'],axis = True)
y= data['variety'].replace(['Setosa','Versicolor','Virginica'],[1,0,0])
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)
model = Perceptron()
model.fit(x_train,y_train)
print('Độ chính xác', model.score(x_train,y_train))
x_input = [[5.5,2.6,4.4,1.2],[5.8,4,1.2,0.2]]
y_output = model.predict(x_input)
print(y_output)
# Out:
# Độ chính xác 1.0
# [0 1]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_iris
import pandas as pd
url = '/content/drive/MyDrive/DOWLOAD/Thư mục không có tiêu đề/iris.csv'
data = pd.read_csv(url)
data = data[:100]
x= data.drop(['variety'],axis = True)
y= data['variety'].replace(['Setosa','Versicolor','Virginica'],[1,0,0])
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)
model = Perceptron()
model.fit(x_train,y_train)
print('Độ chính xác', model.score(x_train,y_train))
x_b = [[6.5,3.6,6.4,3.2],[1.8,4,1.7,0.2]]
y_ra= model.predict(x_b)
print(y_ra)
# Out:
# Độ chính xác 1.0
# [0 1]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   "X does not have valid feature names, but"

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images.shape
train_labels.shape
test_images.shape
test_labels.shape
# Out:
# (10000,)

# %%
import matplotlib.pyplot as plt 
plt.imshow(train_images[5])
plt.show()
print(train_labels[5])
# Out:
# 2

# %%
from tensorflow.python import summary
from keras.layers.serialization import activation
from keras import models
from keras import layers
model= models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
train_images=train_images.reshape((60000,784))
train_images=train_images.astype('float32')/255
test_images=test_images.reshape(10000,784)
test_images=test_images.astype('float32')/255
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 512)               401920
#
#  dense_7 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.datasets import fashion_mnist
from traitlets.traitlets import inspect
from keras.datasets import mnist
import matplotlib.pyplot as mlp
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.metrics import metrics
from keras.layers.serialization import activation
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()
Class_names = ['T-skirt/Tip','Trousers','pullover','dress','coat','sandal','shirt','sneaker','bag','ankle boot']
mlp.imshow(x_train[100])
mlp.show()
print(Class_names[y_train[13]])

model = models.Sequential()
model.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
model.add(layers.Dense(10,activation='softmax'))
model.summary()
x_train=x_train.reshape((60000,28*28))
x_train=x_train.astype('float32')/255
x_test=x_test.reshape((10000,28*28))
y_test=y_test.astype('float32')/255
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)
model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit(x_train,y_train,epochs=10,batch_size=128)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# sandal
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 512)               401920
#
#  dense_9 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.5561 - accuracy: 0.8006
# Epoch 2/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3816 - accuracy: 0.8599
# Epoch 3/10
# 469/469 [==============================] - 6s 13ms/step - loss: 0.3379 - accuracy: 0.8759
# Epoch 4/10
# 469/469 [==============================] - 11s 23ms/step - loss: 0.3105 - accuracy: 0.8866
# Epoch 5/10
# ...

# %%
from keras.datasets import fashion_mnist
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
class_names=['T-shirt/top','Trourers','green','pullover']

# %%
plt.imshow(x_train[100])
plt.show
print(class_names[y_train[25]])
# Out:
# pullover

# %%
from keras.datasets import fashion_mnist
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
from keras.utils import to_categorical
from tensorflow.python import summary
from keras.layers.serialization import activation
from keras import models
from keras import layers
model= models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
model.add(layers.Dense(10, activation='softmax'))
model.summary()
train_images=x_train.reshape((60000,784))
train_images=y_train.astype('float32')/255
test_images=x_test.reshape(10000,784)
test_images=y_test.astype('float32')/255
x_train=to_categorical(x_train)
y_train= to_categorical(y_train)
model.compile(optimizer='rmsprop',loss='categorical_crossentropy' , metrics= 'accuracy' )
model.fit(train_images,train_labels,epochs=10,batch_size=128)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               401920
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import load_img, img_to_array
import numpy as np
url='/content/CALVIN.jpg'
img=load_img(url,target_size=(28,28))
mlp.imshow(img)
img=img_to_array(img)
img=img.reshape(1,28,28,3)
img=img.astype('float32')
img=img/255
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e86e8ad1c76f> in <module>
#       2 import numpy as np
#       3 url='/content/CALVIN.jpg'
# ----> 4 img=load_img(url,target_size=(28,28))
#       5 mlp.imshow(img)
#       6 img=img_to_array(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     391     if isinstance(path, pathlib.Path):
#     392       path = str(path.resolve())
# --> 393     with open(path, 'rb') as f:
#     394       img = pil_image.open(io.BytesIO(f.read()))
#     395   else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/CALVIN.jpg'

# %%
from keras.utils import load_img, img_to_array
import numpy as np
url='/content/CALVIN.jpg'
img=load_img(url,target_size=(28,28))
mlp.imshow(img)
img=img_to_array(img)
img=img.reshape(1,784)
img=img.astype('float32')
img=img/784
np.argmax(model.predict(img),axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1868e3f5fc87> in <module>
#       2 import numpy as np
#       3 url='/content/CALVIN.jpg'
# ----> 4 img=load_img(url,target_size=(28,28))
#       5 mlp.imshow(img)
#       6 img=img_to_array(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     391     if isinstance(path, pathlib.Path):
#     392       path = str(path.resolve())
# --> 393     with open(path, 'rb') as f:
#     394       img = pil_image.open(io.BytesIO(f.read()))
#     395   else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/CALVIN.jpg'

# %%
from keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)= cifar10.load_data()

# %%
from matplotlib import pyplot as plt
from matplotlib.image import imread
for i in range(9):
  plt.subplot(330+1+i)
  plt.imshow(x_train[i])
plt.show()

# %%
from keras.models.cloning import Sequential
from keras import layers
from keras.layers.serialization import activation
from keras.metrics import metrics
from keras.utils import to_categorical
from keras import models
from keras.utils import np_utils
model=models.Sequential()
model.add(layers.Dense(512,activation='relu',input_shape=(1024*3,)))
model.add(layers.Dense(512,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))
x_train=x_train.reshape(50000,1024*3)
x_test=x_test.reshape(10000,1024*3)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_train/=255
x_test/=255
y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)
model.summary()
model.compile(optimizer='rmsprop',loss='categorical_crossentropy' , metrics= ['accuracy'] )
model.fit(x_train,y_train,epochs=10,batch_size=128)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 512)               1573376
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 10)                5130
#
# ...
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 15s 37ms/step - loss: 2.1411 - accuracy: 0.2659
# Epoch 2/10
# 391/391 [==============================] - 14s 36ms/step - loss: 1.7704 - accuracy: 0.3659
# Epoch 3/10
# 391/391 [==============================] - 16s 40ms/step - loss: 1.6746 - accuracy: 0.4051
# Epoch 4/10
# 391/391 [==============================] - 14s 36ms/step - loss: 1.6054 - accuracy: 0.4277
# Epoch 5/10
# ...

# %%
model.save('Chmc.hs')

# %%
from keras.models import load_model
model100=load_model('/content/Chmc.hs')

# %%
from keras.utils import load_img
from keras.utils import img_to_array, load_img 
import matplotlib.pyplot as plt 
import numpy as np
from keras.models import load_model
model1= load_model('/content/Chmc.hs')

# %%
from keras.utils import load_img
from keras.utils import img_to_array,load_img
import matplotlib.pyplot as plt
import numpy as np
from keras.models import load_model
model1 = load_model('/content/Chmc.hs')
img = load_img('/content/tàu tatinic.jpg',target_size=(32,32))
plt.imshow(img)
img = img_to_array(img)
img = img.astype('float32')
img= img.reshape(1,32*32*3)
img = img/255
class_name=['Máy bay','Ô tô','Chim chóc','Mèo','Hươi','Chó','Ếch','Ngựa','Tàu','Xe tải']
print(model.predict(img))
a= int(np.argmax(model.predict(img),axis=1))
print("Đây là:", class_name[a])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-e9bc7766a3dc> in <module>
#       5 from keras.models import load_model
#       6 model1 = load_model('/content/Chmc.hs')
# ----> 7 img = load_img('/content/tàu tatinic.jpg',target_size=(32,32))
#       8 plt.imshow(img)
#       9 img = img_to_array(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     391     if isinstance(path, pathlib.Path):
#     392       path = str(path.resolve())
# --> 393     with open(path, 'rb') as f:
#     394       img = pil_image.open(io.BytesIO(f.read()))
#     395   else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/tàu tatinic.jpg'

# %%
from keras.datasets import mnist
(x_train,y_train),(x_test,y_test)= mnist.load_data()

# %%
from keras.saving.saving_utils import keras
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import MaxPooling2D
from keras import layers
from keras.layers import Flatten
y_train= to_categorical(y_train)
y_test= to_categorical(y_test)
model=Sequential()
model.add(layers.Conv2D(32, kernel_size=(3,3),activation= 'relu', input_shape =(28,28,1), padding='same'))

# %%
from keras.datasets import mnist
(x_train, y_train),(x_test,y_test)=mnist.load_data()

x_train.shape

y_train.shape

x_test.shape

y_test.shape

from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

from keras.layers.pooling.max_pooling2d import MaxPooling2D
from keras import models
from keras.models import Sequential
from keras.layers.serialization import activation
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import layers

model = models.Sequential()
model.add(Conv2D(32, kernel_size=(3,3),activation = 'relu', input_shape = (28,28,1),padding = 'same'))
model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(64, kernel_size=(3,3), activation = 'relu', padding='same'))
model.add(MaxPooling2D((2,2), padding ='same'))
model.add(Conv2D(128,kernel_size=(3,3), activation = 'relu', padding = 'same'))
model.add(MaxPooling2D((2,2), padding ='same'))
model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(Dense(10, activation = 'softmax'))

model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')
history=model.fit(x_train,y_train,epochs=20,batch_size=128,verbose=2)
# Out:
# Epoch 1/20
# 469/469 - 103s - loss: 0.7297 - accuracy: 0.9091 - 103s/epoch - 220ms/step
# Epoch 2/20
# 469/469 - 93s - loss: 0.0522 - accuracy: 0.9837 - 93s/epoch - 199ms/step
# Epoch 3/20
# 469/469 - 96s - loss: 0.0363 - accuracy: 0.9884 - 96s/epoch - 206ms/step
# Epoch 4/20
# 469/469 - 100s - loss: 0.0278 - accuracy: 0.9909 - 100s/epoch - 212ms/step
# Epoch 5/20
# 469/469 - 96s - loss: 0.0223 - accuracy: 0.9926 - 96s/epoch - 204ms/step
# Epoch 6/20
# 469/469 - 97s - loss: 0.0236 - accuracy: 0.9923 - 97s/epoch - 206ms/step
# Epoch 7/20
# 469/469 - 93s - loss: 0.0194 - accuracy: 0.9936 - 93s/epoch - 198ms/step
# Epoch 8/20
# 469/469 - 93s - loss: 0.0180 - accuracy: 0.9940 - 93s/epoch - 198ms/step
# Epoch 9/20
# 469/469 - 96s - loss: 0.0196 - accuracy: 0.9937 - 96s/epoch - 206ms/step
# Epoch 10/20
# 469/469 - 93s - loss: 0.0177 - accuracy: 0.9941 - 93s/epoch - 199ms/step
# Epoch 11/20
# 469/469 - 95s - loss: 0.0168 - accuracy: 0.9943 - 95s/epoch - 204ms/step
# Epoch 12/20
# ...

# %%
test_lost,test_acc=Mod.evaluate(x_test,y_test)
print('Test accuracy:',test_acc)
from keras.utils import load_img
from keras.utils import img_to_array,load_img
import matplotlib.pyplot as plt
import numpy as np
from keras.models import load_model
img = load_img('/content/raw-materials.png',target_size=(28,28))
plt.imshow(img)
img = img_to_array(img)
img = img[:,:,0]
img = img.astype('float32')
img = img.reshape(1,28,28,1)
img = img/255
class_number=['1','2','3','4','5','6','7','8','9','0']
a= int(np.argmax(Mod.predict(img),axis=1))
print("Đây là số:", class_number[a])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4f5603a73148> in <module>
# ----> 1 test_lost,test_acc=Mod.evaluate(x_test,y_test)
#       2 print('Test accuracy:',test_acc)
#       3 from keras.utils import load_img
#       4 from keras.utils import img_to_array,load_img
#       5 import matplotlib.pyplot as plt
#
# NameError: name 'Mod' is not defined

# %%
metric= model.evaluate(x_test, y_test, verbose=2)
print('Sai so',metric[0])
print('Độ Chính xác', metric[1])
plt.plot(history.history['Accuracy'])
plt.plot(history.history['loss'])
plt.title('Độ Chính xác hình')
plt.ylabel('Độ chính xác')
plt.xlabel('Số lần học')
plt.legend(['độ chính xác', 'sai số',], loc='lower right' )

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from keras.utils import to_categorical
from keras.models import load_model
from keras.utils import load_img, img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %%
# %cd /content/drive/MyDrive/DOWLOAD/Flower
# Out:
# /content/drive/MyDrive/DOWLOAD/Flower

# %%
# !ls /content/drive/MyDrive/DOWLOAD/Flower
# Out:
# 'Hoa anh đào'	   'Hoa cát tường'  'Hoa hướng dương'  'Hoa mọc lan'
# 'Hoa ban'	   'Hoa cúc'	    'Hoa lavender'     'Hoa mười giờ'
# 'Hoa bồ công anh'  'Hoa cứt lợn'    'Hoa lay ơn'       'Hoa phong lan'
# 'Hoa cẩm chướng'   'Hoa giấy'	    'Hoa ly'	       'Hoa sen'
# 'Hoa cẩm tú cầu'   'Hoa hồng'	    'Hoa mai'	       'Hoa thủy tiên'

# %%
import numpy as np 
import pandas as pd 
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
import matplotlib.pyplot as plt
# %matplotlib inline
import pathlib 
from glob import glob
from tensorflow.keras.utils import image_dataset_from_directory
import warnings
import os

# %%
labels = os.listdir("/content/drive/MyDrive/DOWLOAD/Flower")
labels
# Out:
# ['Hoa cứt lợn',
#  'Hoa hướng dương',
#  'Hoa cẩm chướng',
#  'Hoa cát tường',
#  'Hoa anh đào',
#  'Hoa ban',
#  'Hoa cúc',
#  'Hoa bồ công anh',
#  'Hoa giấy',
#  'Hoa cẩm tú cầu',
#  'Hoa lavender',
#  'Hoa mọc lan',
#  'Hoa sen',
#  'Hoa ly',
#  'Hoa thủy tiên',
#  'Hoa lay ơn',
#  'Hoa mai',
#  'Hoa hồng',
#  'Hoa phong lan',
#  'Hoa mười giờ']

# %%
lavender_data = plt.imread('/content/drive/MyDrive/DOWLOAD/Flower/Hoa lavender/hoa lavender.jpg')
lavender_data
lavender_data.shape
# Out:
# (535, 803, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('/content/drive/MyDrive/DOWLOAD/Flower/Hoa lavender/hoa lavender.jpg'))

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('/content/drive/MyDrive/DOWLOAD/Flower/Hoa ly/hoa ly.jpg'))

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread('/content/drive/MyDrive/DOWLOAD/Flower/Hoa mai/hoa mai.jpg'))

# %%
moclan_data = plt.imread('/content/drive/MyDrive/DOWLOAD/Flower/Hoa mọc lan/hoa moc lan.jpg')
moclan_data.shape
# Out:
# (740, 743, 3)

# %%
path = '/content/drive/MyDrive/DOWLOAD/Flower'
data_dir = pathlib.Path(path)
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/DOWLOAD/Flower')

# %%
import cv2
def read_image(path):
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image
path
# Out:
# '/content/drive/MyDrive/DOWLOAD/Flower'

# %%
labels = ['Bo cong anh', 'Hoa cuc', 'hoa huong duong', 'hoa ban','hoa giay','hoa lavender','hoa ly','hoa lay on','hoa cut lon','hoa cat tuong','hoa anh dao','hoa mai','hoa moc lan','hoa phong lan', 'Hoa hong']
col_to_title = {'Bo cong anh': 'Bo cong anh', 'Hoa cuc': 'Hoa cuc', 'hoa huong duong': 'hoa huong duong', 'hoa ban':'hoa ban','Hoa hong': 'Hoa hong','hoa giay':'hoa giay','hoa lavender':'hoa lavender','hoa ly':'hoa ly','hoa lay on':'hoa lay on','hoa cut lon':'hoa cut lon','hoa cat tuong':'hoa cat tuong','hoa anh dao':'hoa anh dao','hoa mai':'hoa mai','hoa moc lan':'hoa moc lan','hoa phong lan':'hoa phong lan'}

# %%
flowers_folder = '/content/drive/MyDrive/DOWLOAD/Flower'
flowers_folder
# Out:
# '/content/drive/MyDrive/DOWLOAD/Flower'

# %%
x_train = image_dataset_from_directory(flowers_folder,validation_split=0.3,subset="validation",seed=2500,image_size=(128,128),batch_size=32)
x_test = image_dataset_from_directory(flowers_folder,validation_split=0.3,subset="validation",seed=2500,image_size=(128,128),batch_size=32)
# Out:
# Found 20 files belonging to 20 classes.
# Using 6 files for validation.
# Found 20 files belonging to 20 classes.
# Using 6 files for validation.

# %%
class_name=x_train.class_names
class_name
# Out:
# ['Hoa anh đào',
#  'Hoa ban',
#  'Hoa bồ công anh',
#  'Hoa cát tường',
#  'Hoa cẩm chướng',
#  'Hoa cẩm tú cầu',
#  'Hoa cúc',
#  'Hoa cứt lợn',
#  'Hoa giấy',
#  'Hoa hồng',
#  'Hoa hướng dương',
#  'Hoa lavender',
#  'Hoa lay ơn',
#  'Hoa ly',
#  'Hoa mai',
#  'Hoa mọc lan',
#  'Hoa mười giờ',
#  'Hoa phong lan',
#  'Hoa sen',
#  'Hoa thủy tiên']

# %%
import tensorflow as tf 

AUTOTUNE = tf.data.AUTOTUNE
x_train = x_train.cache().shuffle(buffer_size=6000).prefetch(buffer_size=AUTOTUNE)
x_test = x_test.cache().shuffle(buffer_size=6000).prefetch(buffer_size=AUTOTUNE)

# %%
data_layer=Sequential([layers.RandomFlip(mode='horizontal',input_shape=(128,128,3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1)],name='data_layer')
num_classes=len(class_name)
num_classes
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# 20

# %%
model=Sequential([ data_layer,
    layers.Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(filters=32,kernel_size=3,padding="same", activation="relu"),
    layers.MaxPooling2D(),
    
    layers.Conv2D(filters=64, kernel_size=3, padding="same", activation="relu"),
    layers.MaxPooling2D(),
    
    layers.Dropout(rate=0.2),
    layers.Flatten(),
    
    layers.Dense(units=128, activation="relu"),
    layers.Dense(units=num_classes)])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  data_layer (Sequential)     (None, 128, 128, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten_2 (Flatten)         (None, 16384)             0
#
#  dense_4 (Dense)             (None, 128)               2097280
#
#  dense_5 (Dense)             (None, 20)                2580
#
# ...
# Total params: 2,123,444
# Trainable params: 2,123,444
# Non-trainable params: 0
# ...

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from keras.utils import to_categorical
from keras.models import load_model
from keras.utils import load_img, img_to_array
from keras.preprocessing.image import ImageDataGenerator

# %%
train_data = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
train_set = train_data.flow_from_directory('/content/drive/MyDrive/DOWLOAD/Flower',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 20 images belonging to 21 classes.

# %%
test_set = train_data.flow_from_directory('/content/drive/MyDrive/DOWLOAD/Flower',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 20 images belonging to 21 classes.

# %%
train_set.class_indices
# Out:
# {'Hoa anh đào': 0,
#  'Hoa ban': 1,
#  'Hoa bồ công anh': 2,
#  'Hoa cát tường': 3,
#  'Hoa cẩm chướng': 4,
#  'Hoa cẩm tú cầu': 5,
#  'Hoa cúc': 6,
#  'Hoa cứt lợn': 7,
#  'Hoa giấy': 8,
#  'Hoa hồng': 9,
#  'Hoa hướng dương': 10,
#  'Hoa lavender': 11,
#  'Hoa lay ơn': 12,
#  'Hoa ly': 13,
#  'Hoa mai': 14,
#  'Hoa mọc lan': 15,
#  'Hoa mười giờ': 16,
#  'Hoa phong lan': 17,
#  'Hoa sen': 18,
#  'Hoa thủy tiên': 19,
#  'Nhan_dien_hoa.20': 20}

# %%
test_set.class_indices
# Out:
# {'Hoa anh đào': 0,
#  'Hoa ban': 1,
#  'Hoa bồ công anh': 2,
#  'Hoa cát tường': 3,
#  'Hoa cẩm chướng': 4,
#  'Hoa cẩm tú cầu': 5,
#  'Hoa cúc': 6,
#  'Hoa cứt lợn': 7,
#  'Hoa giấy': 8,
#  'Hoa hồng': 9,
#  'Hoa hướng dương': 10,
#  'Hoa lavender': 11,
#  'Hoa lay ơn': 12,
#  'Hoa ly': 13,
#  'Hoa mai': 14,
#  'Hoa mọc lan': 15,
#  'Hoa mười giờ': 16,
#  'Hoa phong lan': 17,
#  'Hoa sen': 18,
#  'Hoa thủy tiên': 19,
#  'Nhan_dien_hoa.20': 20}

# %%
model=Sequential()

model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(21,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_30 (Conv2D)          (None, 150, 150, 32)      896
#
#  conv2d_31 (Conv2D)          (None, 150, 150, 32)      9248
#
#  max_pooling2d_15 (MaxPoolin  (None, 75, 75, 32)       0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 75, 75, 64)        18496
#
#  conv2d_33 (Conv2D)          (None, 75, 75, 64)        36928
#
#  max_pooling2d_16 (MaxPoolin  (None, 37, 37, 64)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 37, 37, 128)       73856
#
#  conv2d_35 (Conv2D)          (None, 37, 37, 128)       147584
#
#  max_pooling2d_17 (MaxPoolin  (None, 18, 18, 128)      0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 41472)             0
#
#  dense_10 (Dense)            (None, 128)               5308544
#
#  dropout_5 (Dropout)         (None, 128)               0
#
# ...

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_set,epochs=100,batch_size=128,verbose=1, validation_data=test_set, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# 1/1 [==============================] - 4s 4s/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.1584 - accuracy: 0.9500 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.2977 - accuracy: 0.8500 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0972 - accuracy: 0.9500 - val_loss: 0.0643 - val_accuracy: 0.9500
# Epoch 82/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.4507 - accuracy: 0.9500 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.0784 - accuracy: 0.9500 - val_loss: 0.0137 - val_accuracy: 1.0000
# ...

# %%
model.save('Nhan_dien_hoa.2')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.

# %%
model_hoa = load_model('Nhan_dien_hoa.2')

# %%
Score=model.evaluate(train_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.0048069339245557785
# Train Accuracy 1.0

# %%
img = load_img('/content/hoa cuc.jpg',target_size = (150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_hoa.predict(img)
class_hoa=['mai','cẩm tú cầu','ly','lavender','hồng','anh đào', 'cuc']
a= int(np.argmax(model.predict(img),axis=1))
print("Đây là hoa:", class_hoa[a])
# Out:
# ...
# 1/1 [==============================] - 0s 85ms/step
# Đây là hoa: cuc
